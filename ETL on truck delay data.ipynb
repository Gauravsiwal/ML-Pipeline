# %% [markdown]
# # Extract- Connecting to database servers

# %%
import numpy as np
import pandas as pd
import pymysql
import psycopg2
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Data from postgreSQL

# %%
postgres_connection = psycopg2.connect(
    user='*****',
    password='*****',
    host='localhost',
    database='TruckDelay',
    port='5432')

# %%
routes_df = pd.read_sql_query('select * from routes_details', postgres_connection)

# %%
routes_df.head(2)
# Out:
#      route_id   origin_id destination_id  distance  average_hours
# 0  R-ada2a391  C-927ceb5e     C-56e39a5e   1735.06          34.70
# 1  R-ae0ef31f  C-927ceb5e     C-73ae5412   1498.24          29.96

# %%
routes_weather = pd.read_sql_query('select * from routes_weather', postgres_connection)

# %%
routes_weather.head(2)
# Out:
#      route_id                Date  temp  wind_speed description  precip  \
# 0  R-ada2a391 2019-01-01 00:00:00  30.0        11.0  Heavy snow     0.0
# 1  R-ada2a391 2019-01-01 06:00:00  30.0        11.0  Heavy snow     0.0
#
#    humidity  visibility  pressure  chanceofrain  chanceoffog  chanceofsnow  \
# 0        90         1.0      1010             0            0             0
# 1        91         3.0      1012             0            0             0
#
#    chanceofthunder
# 0                0
# 1                0

# %%
postgres_connection.close()

# %% [markdown]
# ## Data from MySQL

# %%
mysql_connection = pymysql.connect(
    user='*****',
    passwd='*****',
    db='truck_delay',
    host='127.0.0.1',
    port=3306)

# %%
pd.read_sql_query('show tables',mysql_connection)
# Out:
#   Tables_in_truck_delay
# 0          city_weather
# 1       drivers_details
# 2       traffic_details
# 3         truck_details
# 4   truck_schedule_data

# %%
truck_df = pd.read_sql_query('select * from truck_details',mysql_connection)
traffic_df = pd.read_sql_query('select * from traffic_details',mysql_connection)
driver_df = pd.read_sql_query('select * from drivers_details',mysql_connection)
weather_df = pd.read_sql_query('select * from city_weather',mysql_connection)
schedule_df = pd.read_sql_query('select * from truck_schedule_data',mysql_connection)

# %%
truck_df.head(2)
# Out:
#    truck_id  truck_age  load_capacity_pounds  mileage_mpg fuel_type
# 0  42302347         10                3000.0           17       gas
# 1  27867488         14               10000.0           22    diesel

# %%
traffic_df.head(2)
# Out:
#      route_id        date  hour  no_of_vehicles  accident
# 0  R-ada2a391  2019-01-01     0           669.0         0
# 1  R-ada2a391  2019-01-01   100           628.0         0

# %%
driver_df.head(2)
# Out:
#     driver_id           name gender  age  experience driving_style  ratings  \
# 0  d9f30553-6   Daniel Marks   male   47           5     proactive        7
# 1  82de7bb8-2  Clifford Carr   male   47          14     proactive        4
#
#    vehicle_no  average_speed_mph
# 0    42302347              62.22
# 1    27867488              60.89

# %%
weather_df.head(2)
# Out:
#       city_id        date  hour  temp  wind_speed description  precip  \
# 0  C-927ceb5e  2019-01-01     0  30.0        11.0  Light snow     0.0
# 1  C-927ceb5e  2019-01-01   100  28.0        12.0  Light snow     0.0
#
#    humidity  visibility  pressure  chanceofrain  chanceoffog  chanceofsnow  \
# 0        86         6.0    1019.0           0.0          0.0           0.0
# 1        86         5.0    1021.0           0.0          0.0           0.0
#
#    chanceofthunder
# 0              0.0
# 1              0.0

# %%
schedule_df.head(2)
# Out:
#    truck_id    route_id      departure_date     estimated_arrival  delay
# 0  30312694  R-b236e347 2019-01-01 07:00:00  2019-01-01 13:13:12.      0
# 1  59856374  R-29ea762e 2019-01-01 07:00:00  2019-01-02 04:01:12.      0

# %% [markdown]
# # Transform : Data Cleaning, Feature Engineering and Merging

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# To avoid data leakage missing values will be treated after train test split

# %%
# Lets take the wether data and drop uncecessary columns
weather_df.head(2)
# Out:
#       city_id        date  hour  temp  wind_speed description  precip  \
# 0  C-927ceb5e  2019-01-01     0  30.0        11.0  Light snow     0.0
# 1  C-927ceb5e  2019-01-01   100  28.0        12.0  Light snow     0.0
#
#    humidity  visibility  pressure  chanceofrain  chanceoffog  chanceofsnow  \
# 0        86         6.0    1019.0           0.0          0.0           0.0
# 1        86         5.0    1021.0           0.0          0.0           0.0
#
#    chanceofthunder
# 0              0.0
# 1              0.0

# %%
weather_df.drop(columns=['chanceofrain','chanceoffog','chanceofsnow','chanceofthunder'],inplace=True)

# %%
weather_df.head(2)
# Out:
#       city_id        date  hour  temp  wind_speed description  precip  \
# 0  C-927ceb5e  2019-01-01     0  30.0        11.0  Light snow     0.0
# 1  C-927ceb5e  2019-01-01   100  28.0        12.0  Light snow     0.0
#
#    humidity  visibility  pressure
# 0        86         6.0    1019.0
# 1        86         5.0    1021.0

# %%
# convert hour to 4 digit string format
weather_df['hour'] = weather_df['hour'].apply(lambda x: f'{x:04d}')

# convert hour to time format
weather_df['hour'] = pd.to_datetime(weather_df['hour'],format='%H%M').dt.time

# %%
weather_df.head(2)
# Out:
#       city_id        date      hour  temp  wind_speed description  precip  \
# 0  C-927ceb5e  2019-01-01  00:00:00  30.0        11.0  Light snow     0.0
# 1  C-927ceb5e  2019-01-01  01:00:00  28.0        12.0  Light snow     0.0
#
#    humidity  visibility  pressure
# 0        86         6.0    1019.0
# 1        86         5.0    1021.0

# %%
# Lets combine hour and date and create a new column custom date

custom_date = pd.to_datetime(weather_df['date'].astype('str')+' '+weather_df['hour'].astype('str'))

# %%
weather_df.insert(loc=1,column='custom_date',value=custom_date)

# %%
weather_df.head(2)
# Out:
#       city_id         custom_date        date      hour  temp  wind_speed  \
# 0  C-927ceb5e 2019-01-01 00:00:00  2019-01-01  00:00:00  30.0        11.0
# 1  C-927ceb5e 2019-01-01 01:00:00  2019-01-01  01:00:00  28.0        12.0
#
#   description  precip  humidity  visibility  pressure
# 0  Light snow     0.0        86         6.0    1019.0
# 1  Light snow     0.0        86         5.0    1021.0

# %%
# Now lets remove unnecesary columns from route wether
routes_weather.head(2)
# Out:
#      route_id                Date  temp  wind_speed description  precip  \
# 0  R-ada2a391 2019-01-01 00:00:00  30.0        11.0  Heavy snow     0.0
# 1  R-ada2a391 2019-01-01 06:00:00  30.0        11.0  Heavy snow     0.0
#
#    humidity  visibility  pressure  chanceofrain  chanceoffog  chanceofsnow  \
# 0        90         1.0      1010             0            0             0
# 1        91         3.0      1012             0            0             0
#
#    chanceofthunder
# 0                0
# 1                0

# %%
routes_weather.drop(columns=['chanceofrain','chanceoffog','chanceofsnow','chanceofthunder'],inplace=True)

# %%
routes_weather.head(2)
# Out:
#      route_id                Date  temp  wind_speed description  precip  \
# 0  R-ada2a391 2019-01-01 00:00:00  30.0        11.0  Heavy snow     0.0
# 1  R-ada2a391 2019-01-01 06:00:00  30.0        11.0  Heavy snow     0.0
#
#    humidity  visibility  pressure
# 0        90         1.0      1010
# 1        91         3.0      1012

# %%
# Now let us look at traffic data

# %%
traffic_df.head(2)
# Out:
#      route_id        date  hour  no_of_vehicles  accident
# 0  R-ada2a391  2019-01-01     0           669.0         0
# 1  R-ada2a391  2019-01-01   100           628.0         0

# %%
# create custom date column
traffic_df['hour'] = traffic_df['hour'].apply(lambda x: f'{x:04d}')

traffic_df['hour'] = pd.to_datetime(traffic_df['hour'],format='%H%M').dt.time

# %%
custom_date = pd.to_datetime(traffic_df['date'].astype('str')+' '+traffic_df['hour'].astype('str'))

# %%
traffic_df.insert(1,'custom_date',custom_date)

# %%
traffic_df.head(2)
# Out:
#      route_id         custom_date        date      hour  no_of_vehicles  \
# 0  R-ada2a391 2019-01-01 00:00:00  2019-01-01  00:00:00           669.0
# 1  R-ada2a391 2019-01-01 01:00:00  2019-01-01  01:00:00           628.0
#
#    accident
# 0         0
# 1         0

# %% [markdown]
# ## Feature Engineering

# %%
# Merge route wether with schedule data

# %%
routes_weather.head(3)
# Out:
#      route_id                Date  temp  wind_speed description  precip  \
# 0  R-ada2a391 2019-01-01 00:00:00  30.0        11.0  Heavy snow     0.0
# 1  R-ada2a391 2019-01-01 06:00:00  30.0        11.0  Heavy snow     0.0
# 2  R-ada2a391 2019-01-02 00:00:00  28.0        11.0      Cloudy     0.0
#
#    humidity  visibility  pressure
# 0        90         1.0      1010
# 1        91         3.0      1012
# 2        91         4.0      1013

# %%
schedule_df.head(3)
# Out:
#    truck_id    route_id      departure_date     estimated_arrival  delay
# 0  30312694  R-b236e347 2019-01-01 07:00:00  2019-01-01 13:13:12.      0
# 1  59856374  R-29ea762e 2019-01-01 07:00:00  2019-01-02 04:01:12.      0
# 2  12602955  R-a3d67783 2019-01-01 07:00:00  2019-01-01 07:45:36.      0

# %%
# Add unique value to rows in schedule df
schedule_df.insert(0,'unique_id',np.arange(len(schedule_df)))

# %%
schedule_df['estimated_arrival']=pd.to_datetime(schedule_df['estimated_arrival'])

# %%
schedule_df_nearest_6h = schedule_df.copy()

# %%
schedule_df_nearest_6h['departure_date']=schedule_df_nearest_6h['departure_date'].dt.floor('6H')
schedule_df_nearest_6h['estimated_arrival']=schedule_df_nearest_6h['estimated_arrival'].dt.ceil('6H')

# %%
schedule_df_nearest_6h
# Out:
#        unique_id  truck_id    route_id      departure_date  \
# 0              0  30312694  R-b236e347 2019-01-01 06:00:00
# 1              1  59856374  R-29ea762e 2019-01-01 06:00:00
# 2              2  12602955  R-a3d67783 2019-01-01 06:00:00
# 3              3  46619422  R-31ec9310 2019-01-01 06:00:00
# 4              4  10140178  R-a07c5dbd 2019-01-01 06:00:00
# ...          ...       ...         ...                 ...
# 12303      12303  31047945  R-1484a7ea 2019-02-06 06:00:00
# 12304      12304  14758432  R-927cf900 2019-02-06 06:00:00
# 12305      12305  31370619  R-5a83ad98 2019-02-06 06:00:00
# 12306      12306  67332883  R-991530bc 2019-02-06 06:00:00
# 12307      12307  26630473  R-3f49bd43 2019-02-06 06:00:00
#
#         estimated_arrival  delay
# 0     2019-01-01 18:00:00      0
# 1     2019-01-02 06:00:00      0
# 2     2019-01-01 12:00:00      0
# 3     2019-01-02 00:00:00      0
# 4     2019-01-02 00:00:00      0
# ...                   ...    ...
# 12303 2019-02-14 00:00:00      0
# 12304 2019-02-14 00:00:00      1
# 12305 2019-02-14 12:00:00      1
# 12306 2019-02-13 12:00:00      1
# 12307 2019-02-14 06:00:00      1
#
# [12308 rows x 6 columns]

# %%
date_6h_range = [pd.date_range(start,end,freq='6H') for start,end in 
 zip(schedule_df_nearest_6h['departure_date'], schedule_df_nearest_6h['estimated_arrival'])]

# %%
schedule_df_nearest_6h['Date']= date_6h_range

# %%
schedule_df_exploded_6h = schedule_df_nearest_6h.explode('Date',ignore_index=False)

# %%
schedule_df_exploded_6h.head(3)
# Out:
#    unique_id  truck_id    route_id      departure_date   estimated_arrival  \
# 0          0  30312694  R-b236e347 2019-01-01 06:00:00 2019-01-01 18:00:00
# 0          0  30312694  R-b236e347 2019-01-01 06:00:00 2019-01-01 18:00:00
# 0          0  30312694  R-b236e347 2019-01-01 06:00:00 2019-01-01 18:00:00
#
#    delay                Date
# 0      0 2019-01-01 06:00:00
# 0      0 2019-01-01 12:00:00
# 0      0 2019-01-01 18:00:00

# %%
schedule_df_exploded_6h.shape
# Out:
# (71376, 7)

# %%
schedule_weather = schedule_df_exploded_6h.merge(routes_weather,on=['Date','route_id'],how='left')

# %%
schedule_weather.head(3)
# Out:
#    unique_id  truck_id    route_id      departure_date   estimated_arrival  \
# 0          0  30312694  R-b236e347 2019-01-01 06:00:00 2019-01-01 18:00:00
# 1          0  30312694  R-b236e347 2019-01-01 06:00:00 2019-01-01 18:00:00
# 2          0  30312694  R-b236e347 2019-01-01 06:00:00 2019-01-01 18:00:00
#
#    delay                Date  temp  wind_speed description  precip  humidity  \
# 0      0 2019-01-01 06:00:00  39.0         5.0  Light rain     0.0        98
# 1      0 2019-01-01 12:00:00  23.0         4.0       Clear     0.0        76
# 2      0 2019-01-01 18:00:00  23.0         4.0       Clear     0.0        73
#
#    visibility  pressure
# 0         6.0      1008
# 1         6.0      1011
# 2         6.0      1011

# %%
schedule_weather.isnull().sum()
# Out:
# unique_id            0
# truck_id             0
# route_id             0
# departure_date       0
# estimated_arrival    0
# delay                0
# Date                 0
# temp                 0
# wind_speed           0
# description          0
# precip               0
# humidity             0
# visibility           0
# pressure             0
# dtype: int64

# %%
schedule_weather_grp = schedule_weather.groupby(by=['unique_id','truck_id','route_id']).agg(
    route_avg_temp = ('temp','mean'),
    route_avg_wind = ('wind_speed','mean'),
    route_description = ('description',(lambda x: x.mode()[0])),
    route_avg_precip = ('precip','mean'),
    route_avg_humidity = ('humidity','mean'),
    route_avg_visibility = ('visibility','mean'),
    route_avg_pressure = ('pressure','mean'))

# %%
schedule_weather_merge = schedule_df.merge(schedule_weather_grp,on=['unique_id','truck_id','route_id'],how='left')

# %%
schedule_weather_merge.head(3)
# Out:
#    unique_id  truck_id    route_id      departure_date   estimated_arrival  \
# 0          0  30312694  R-b236e347 2019-01-01 07:00:00 2019-01-01 13:13:12
# 1          1  59856374  R-29ea762e 2019-01-01 07:00:00 2019-01-02 04:01:12
# 2          2  12602955  R-a3d67783 2019-01-01 07:00:00 2019-01-01 07:45:36
#
#    delay  route_avg_temp  route_avg_wind route_description  route_avg_precip  \
# 0      0       28.333333        4.333333             Clear               0.0
# 1      0       40.000000       10.600000          Overcast               0.0
# 2      0       24.000000        7.500000             Clear               0.0
#
#    route_avg_humidity  route_avg_visibility  route_avg_pressure
# 0           82.333333                   6.0              1010.0
# 1           78.800000                   6.0              1022.2
# 2           63.500000                   6.0              1020.0

# %%
schedule_weather_merge.isnull().sum()
# Out:
# unique_id               0
# truck_id                0
# route_id                0
# departure_date          0
# estimated_arrival       0
# delay                   0
# route_avg_temp          0
# route_avg_wind          0
# route_description       0
# route_avg_precip        0
# route_avg_humidity      0
# route_avg_visibility    0
# route_avg_pressure      0
# dtype: int64

# %% [markdown]
# Creating destination and source city weather

# %%
weather_df.head(3)
# Out:
#       city_id         custom_date        date      hour  temp  wind_speed  \
# 0  C-927ceb5e 2019-01-01 00:00:00  2019-01-01  00:00:00  30.0        11.0
# 1  C-927ceb5e 2019-01-01 01:00:00  2019-01-01  01:00:00  28.0        12.0
# 2  C-927ceb5e 2019-01-01 02:00:00  2019-01-01  02:00:00  28.0        13.0
#
#      description  precip  humidity  visibility  pressure
# 0     Light snow     0.0        86         6.0    1019.0
# 1     Light snow     0.0        86         5.0    1021.0
# 2  Moderate snow     0.0        85         4.0    1022.0

# %%
routes_df.head(3)
# Out:
#      route_id   origin_id destination_id  distance  average_hours
# 0  R-ada2a391  C-927ceb5e     C-56e39a5e   1735.06          34.70
# 1  R-ae0ef31f  C-927ceb5e     C-73ae5412   1498.24          29.96
# 2  R-4beec5fd  C-927ceb5e     C-4fe0fa24   6078.46         121.57

# %%
schedule_weather_merge.merge(routes_df,on=['route_id'],how='left')
# Out:
#        unique_id  truck_id    route_id      departure_date  \
# 0              0  30312694  R-b236e347 2019-01-01 07:00:00
# 1              1  59856374  R-29ea762e 2019-01-01 07:00:00
# 2              2  12602955  R-a3d67783 2019-01-01 07:00:00
# 3              3  46619422  R-31ec9310 2019-01-01 07:00:00
# 4              4  10140178  R-a07c5dbd 2019-01-01 07:00:00
# ...          ...       ...         ...                 ...
# 12303      12303  31047945  R-1484a7ea 2019-02-06 07:00:00
# 12304      12304  14758432  R-927cf900 2019-02-06 07:00:00
# 12305      12305  31370619  R-5a83ad98 2019-02-06 07:00:00
# 12306      12306  67332883  R-991530bc 2019-02-06 07:00:00
# 12307      12307  26630473  R-3f49bd43 2019-02-06 07:00:00
#
#         estimated_arrival  delay  route_avg_temp  route_avg_wind  \
# 0     2019-01-01 13:13:12      0       28.333333        4.333333
# 1     2019-01-02 04:01:12      0       40.000000       10.600000
# 2     2019-01-01 07:45:36      0       24.000000        7.500000
# 3     2019-01-01 20:46:48      0       40.250000        5.250000
# 4     2019-01-01 21:34:11      0       19.500000        4.500000
# ...                   ...    ...             ...             ...
# 12303 2019-02-13 22:40:12      0       60.500000        7.625000
# 12304 2019-02-13 18:52:48      1       53.500000        4.218750
# 12305 2019-02-14 08:01:48      1       61.029412        4.382353
# 12306 2019-02-13 11:14:24      1       45.866667        7.533333
# 12307 2019-02-14 02:52:12      1       57.424242       10.757576
#
#        route_description  route_avg_precip  route_avg_humidity  \
# 0                  Clear          0.000000           82.333333
# 1               Overcast          0.000000           78.800000
# 2                  Clear          0.000000           63.500000
# 3                  Clear          0.000000           84.500000
# 4                    Fog          0.000000           99.500000
# ...                  ...               ...                 ...
# 12303  Light rain shower          0.037500           93.312500
# 12304              Sunny          0.012500           57.625000
# 12305              Sunny          0.000000           80.058824
# 12306  Patchy light snow          0.000000           72.233333
# 12307              Sunny          0.009091           76.757576
#
#        route_avg_visibility  route_avg_pressure   origin_id destination_id  \
# 0                  6.000000         1010.000000  C-927ceb5e     C-d80a1e7d
# 1                  6.000000         1022.200000  C-927ceb5e     C-639c5e36
# 2                  6.000000         1020.000000  C-927ceb5e     C-a9f2c329
# 3                  6.000000         1011.250000  C-927ceb5e     C-c7cacd1d
# 4                  2.500000         1015.000000  C-927ceb5e     C-ef47bdcd
# ...                     ...                 ...         ...            ...
# 12303              4.312500         1007.187500  C-34ae77b0     C-731988ba
# 12304              5.687500         1013.093750  C-34ae77b0     C-a9f2c329
# 12305              5.235294         1012.558824  C-34ae77b0     C-c7cacd1d
# 12306              4.500000         1023.233333  C-34ae77b0     C-84f378bb
# 12307              5.787879         1015.606061  C-34ae77b0     C-c4565ee8
#
#        distance  average_hours
# 0        310.75           6.22
# 1       1050.84          21.02
# 2         38.10           0.76
# 3        688.91          13.78
# 4        728.40          14.57
# ...         ...            ...
# 12303   9183.35         183.67
# 12304   8994.17         179.88
# 12305   9651.62         193.03
# 12306   8611.88         172.24
# 12307   9393.29         187.87
#
# [12308 rows x 17 columns]

# %%
weather_df
# Out:
#           city_id         custom_date        date      hour  temp  wind_speed  \
# 0      C-927ceb5e 2019-01-01 00:00:00  2019-01-01  00:00:00  30.0        11.0
# 1      C-927ceb5e 2019-01-01 01:00:00  2019-01-01  01:00:00  28.0        12.0
# 2      C-927ceb5e 2019-01-01 02:00:00  2019-01-01  02:00:00  28.0        13.0
# 3      C-927ceb5e 2019-01-01 03:00:00  2019-01-01  03:00:00  28.0        14.0
# 4      C-927ceb5e 2019-01-01 04:00:00  2019-01-01  04:00:00  28.0        13.0
# ...           ...                 ...         ...       ...   ...         ...
# 55171  C-594514f8 2019-02-15 19:00:00  2019-02-15  19:00:00  23.0         3.0
# 55172  C-594514f8 2019-02-15 20:00:00  2019-02-15  20:00:00  23.0         3.0
# 55173  C-594514f8 2019-02-15 21:00:00  2019-02-15  21:00:00  23.0         3.0
# 55174  C-594514f8 2019-02-15 22:00:00  2019-02-15  22:00:00  23.0         2.0
# 55175  C-594514f8 2019-02-15 23:00:00  2019-02-15  23:00:00  23.0         2.0
#
#          description  precip  humidity  visibility  pressure
# 0         Light snow     0.0        86         6.0    1019.0
# 1         Light snow     0.0        86         5.0    1021.0
# 2      Moderate snow     0.0        85         4.0    1022.0
# 3      Moderate snow     0.0        84         3.0    1024.0
# 4      Moderate snow     0.0        84         3.0    1025.0
# ...              ...     ...       ...         ...       ...
# 55171         Cloudy     0.0        74         6.0    1018.0
# 55172     Light snow     0.0        74         6.0    1018.0
# 55173     Light snow     0.0        75         6.0    1019.0
# 55174     Light snow     0.0        75         6.0    1019.0
# 55175     Light snow     0.0        75         6.0    1019.0
#
# [55176 rows x 11 columns]

# %%
schedule_wether_copy = schedule_weather_merge.copy()

# %%
schedule_wether_copy = schedule_wether_copy.merge(routes_df,on='route_id',how='left')

# %%
schedule_wether_copy['departure_date'] = schedule_wether_copy['departure_date'].dt.round('1h')
schedule_wether_copy['estimated_arrival']=schedule_wether_copy['estimated_arrival'].dt.round('1h')

# %%
date_range = [pd.date_range(start,stop,freq='1h') for start,stop in
             zip(schedule_wether_copy['departure_date'],schedule_wether_copy['estimated_arrival'])]

# %%
schedule_wether_copy['date']=date_range

# %%
schedule_wether_copy = schedule_wether_copy.explode('date')

# %%
schedule_wether_city_copy = schedule_wether_copy.merge(weather_df,
                           left_on=['origin_id','date'],right_on=['city_id','custom_date'],
                           how='left')

# %%
schedule_wether_city_copy.columns
# Out:
# Index(['unique_id', 'truck_id', 'route_id', 'departure_date',
#        'estimated_arrival', 'delay', 'route_avg_temp', 'route_avg_wind',
#        'route_description', 'route_avg_precip', 'route_avg_humidity',
#        'route_avg_visibility', 'route_avg_pressure', 'origin_id',
#        'destination_id', 'distance', 'average_hours', 'date_x', 'city_id',
#        'custom_date', 'date_y', 'hour', 'temp', 'wind_speed', 'description',
#        'precip', 'humidity', 'visibility', 'pressure'],
#       dtype='object')

# %%
origin_wether_df = schedule_wether_city_copy.groupby(by=['route_id','origin_id'],as_index=False).agg(
    origin_avg_temp = ('temp','mean'),
    origin_avg_wind = ('wind_speed','mean'),
    origin_description = ('description',(lambda x: x.mode()[0])),
    origin_avg_precip = ('precip','mean'),
    origin_avg_humidity = ('humidity','mean'),
    origin_avg_visibility = ('visibility','mean'),
    origin_avg_pressure = ('pressure','mean'))

# %%
origin_wether_df.isnull().sum()
# Out:
# route_id                 0
# origin_id                0
# origin_avg_temp          0
# origin_avg_wind          0
# origin_description       0
# origin_avg_precip        0
# origin_avg_humidity      0
# origin_avg_visibility    0
# origin_avg_pressure      0
# dtype: int64

# %%
schedule_wether_city_copy = schedule_wether_copy.merge(weather_df,
                           left_on=['destination_id','date'],right_on=['city_id','custom_date'],
                           how='left')

# %%
destination_wether_df = schedule_wether_city_copy.groupby(by=['route_id','destination_id'],as_index=False).agg(
    dest_avg_temp = ('temp','mean'),
    dest_avg_wind = ('wind_speed','mean'),
    dest_description = ('description',(lambda x: x.mode()[0])),
    dest_avg_precip = ('precip','mean'),
    dest_avg_humidity = ('humidity','mean'),
    dest_avg_visibility = ('visibility','mean'),
    dest_avg_pressure = ('pressure','mean'))

# %%
destination_wether_df.isnull().sum()
# Out:
# route_id               0
# destination_id         0
# dest_avg_temp          0
# dest_avg_wind          0
# dest_description       0
# dest_avg_precip        0
# dest_avg_humidity      0
# dest_avg_visibility    0
# dest_avg_pressure      0
# dtype: int64

# %%
# merge schedule_wether, origin_wether and destination_wether

# %%
schedule_weather_origin_merge = schedule_weather_merge.merge(origin_wether_df,on='route_id',how='left')

# %%
schedule_weather_origin_dest_merge = schedule_weather_origin_merge.merge(destination_wether_df,
                                                                         on='route_id',how='left')

# %%
schedule_weather_origin_dest_merge.columns
# Out:
# Index(['unique_id', 'truck_id', 'route_id', 'departure_date',
#        'estimated_arrival', 'delay', 'route_avg_temp', 'route_avg_wind',
#        'route_description', 'route_avg_precip', 'route_avg_humidity',
#        'route_avg_visibility', 'route_avg_pressure', 'origin_id',
#        'origin_avg_temp', 'origin_avg_wind', 'origin_description',
#        'origin_avg_precip', 'origin_avg_humidity', 'origin_avg_visibility',
#        'origin_avg_pressure', 'destination_id', 'dest_avg_temp',
#        'dest_avg_wind', 'dest_description', 'dest_avg_precip',
#        'dest_avg_humidity', 'dest_avg_visibility', 'dest_avg_pressure'],
#       dtype='object')

# %%
# Next we need to merge traffic_df

# %%
swod_merge_copy = schedule_weather_origin_dest_merge.copy()

# %%
swod_merge_copy['departure_date'] = swod_merge_copy['departure_date'].dt.round('1h')
swod_merge_copy['estimated_arrival'] = swod_merge_copy['estimated_arrival'].dt.round('1h')

# %%
date_range = [pd.date_range(start,stop,freq='1h') for start,stop in
              zip(swod_merge_copy['departure_date'],swod_merge_copy['estimated_arrival'])]

# %%
swod_merge_copy['custom_date'] = date_range

# %%
swod_merge_copy = swod_merge_copy.explode('custom_date')

# %%
swod_merge_copy
# Out:
#        unique_id  truck_id    route_id      departure_date  \
# 0              0  30312694  R-b236e347 2019-01-01 07:00:00
# 0              0  30312694  R-b236e347 2019-01-01 07:00:00
# 0              0  30312694  R-b236e347 2019-01-01 07:00:00
# 0              0  30312694  R-b236e347 2019-01-01 07:00:00
# 0              0  30312694  R-b236e347 2019-01-01 07:00:00
# ...          ...       ...         ...                 ...
# 12307      12307  26630473  R-3f49bd43 2019-02-06 07:00:00
# 12307      12307  26630473  R-3f49bd43 2019-02-06 07:00:00
# 12307      12307  26630473  R-3f49bd43 2019-02-06 07:00:00
# 12307      12307  26630473  R-3f49bd43 2019-02-06 07:00:00
# 12307      12307  26630473  R-3f49bd43 2019-02-06 07:00:00
#
#         estimated_arrival  delay  route_avg_temp  route_avg_wind  \
# 0     2019-01-01 13:00:00      0       28.333333        4.333333
# 0     2019-01-01 13:00:00      0       28.333333        4.333333
# 0     2019-01-01 13:00:00      0       28.333333        4.333333
# 0     2019-01-01 13:00:00      0       28.333333        4.333333
# 0     2019-01-01 13:00:00      0       28.333333        4.333333
# ...                   ...    ...             ...             ...
# 12307 2019-02-14 03:00:00      1       57.424242       10.757576
# 12307 2019-02-14 03:00:00      1       57.424242       10.757576
# 12307 2019-02-14 03:00:00      1       57.424242       10.757576
# 12307 2019-02-14 03:00:00      1       57.424242       10.757576
# 12307 2019-02-14 03:00:00      1       57.424242       10.757576
#
#       route_description  route_avg_precip  ...  origin_avg_pressure  \
# 0                 Clear          0.000000  ...          1020.892857
# 0                 Clear          0.000000  ...          1020.892857
# 0                 Clear          0.000000  ...          1020.892857
# 0                 Clear          0.000000  ...          1020.892857
# 0                 Clear          0.000000  ...          1020.892857
# ...                 ...               ...  ...                  ...
# 12307             Sunny          0.009091  ...          1009.783069
# 12307             Sunny          0.009091  ...          1009.783069
# 12307             Sunny          0.009091  ...          1009.783069
# 12307             Sunny          0.009091  ...          1009.783069
# 12307             Sunny          0.009091  ...          1009.783069
#
#        destination_id  dest_avg_temp dest_avg_wind  dest_description  \
# 0          C-d80a1e7d      31.214286      9.392857     Light drizzle
# 0          C-d80a1e7d      31.214286      9.392857     Light drizzle
# 0          C-d80a1e7d      31.214286      9.392857     Light drizzle
# 0          C-d80a1e7d      31.214286      9.392857     Light drizzle
# 0          C-d80a1e7d      31.214286      9.392857     Light drizzle
# ...               ...            ...           ...               ...
# 12307      C-c4565ee8      36.507937      8.671958             Sunny
# 12307      C-c4565ee8      36.507937      8.671958             Sunny
# 12307      C-c4565ee8      36.507937      8.671958             Sunny
# 12307      C-c4565ee8      36.507937      8.671958             Sunny
# 12307      C-c4565ee8      36.507937      8.671958             Sunny
#
#        dest_avg_precip dest_avg_humidity  dest_avg_visibility  \
# 0             0.007143         78.000000             4.375000
# 0             0.007143         78.000000             4.375000
# 0             0.007143         78.000000             4.375000
# 0             0.007143         78.000000             4.375000
# 0             0.007143         78.000000             4.375000
# ...                ...               ...                  ...
# 12307         0.010582         74.161376             4.891534
# 12307         0.010582         74.161376             4.891534
# 12307         0.010582         74.161376             4.891534
# 12307         0.010582         74.161376             4.891534
# 12307         0.010582         74.161376             4.891534
#
#        dest_avg_pressure         custom_date
# 0            1018.785714 2019-01-01 07:00:00
# 0            1018.785714 2019-01-01 08:00:00
# 0            1018.785714 2019-01-01 09:00:00
# 0            1018.785714 2019-01-01 10:00:00
# 0            1018.785714 2019-01-01 11:00:00
# ...                  ...                 ...
# 12307        1019.277778 2019-02-13 23:00:00
# 12307        1019.277778 2019-02-14 00:00:00
# 12307        1019.277778 2019-02-14 01:00:00
# 12307        1019.277778 2019-02-14 02:00:00
# 12307        1019.277778 2019-02-14 03:00:00
#
# [317379 rows x 30 columns]

# %%
swodt_merge_copy = swod_merge_copy.merge(traffic_df,on=['route_id','custom_date'],how='left')

# %%
traffic_data = swodt_merge_copy.groupby(by='route_id',as_index=False).agg(
    avg_nov = ('no_of_vehicles','mean'),
    accident = ('accident',(lambda x: 1 if any(x==1) else 0)))

# %%
swodt_merge = schedule_weather_origin_dest_merge.merge(traffic_data,on='route_id',
                                                      how='left')

# %%
swodt_merge
# Out:
#        unique_id  truck_id    route_id      departure_date  \
# 0              0  30312694  R-b236e347 2019-01-01 07:00:00
# 1              1  59856374  R-29ea762e 2019-01-01 07:00:00
# 2              2  12602955  R-a3d67783 2019-01-01 07:00:00
# 3              3  46619422  R-31ec9310 2019-01-01 07:00:00
# 4              4  10140178  R-a07c5dbd 2019-01-01 07:00:00
# ...          ...       ...         ...                 ...
# 12303      12303  31047945  R-1484a7ea 2019-02-06 07:00:00
# 12304      12304  14758432  R-927cf900 2019-02-06 07:00:00
# 12305      12305  31370619  R-5a83ad98 2019-02-06 07:00:00
# 12306      12306  67332883  R-991530bc 2019-02-06 07:00:00
# 12307      12307  26630473  R-3f49bd43 2019-02-06 07:00:00
#
#         estimated_arrival  delay  route_avg_temp  route_avg_wind  \
# 0     2019-01-01 13:13:12      0       28.333333        4.333333
# 1     2019-01-02 04:01:12      0       40.000000       10.600000
# 2     2019-01-01 07:45:36      0       24.000000        7.500000
# 3     2019-01-01 20:46:48      0       40.250000        5.250000
# 4     2019-01-01 21:34:11      0       19.500000        4.500000
# ...                   ...    ...             ...             ...
# 12303 2019-02-13 22:40:12      0       60.500000        7.625000
# 12304 2019-02-13 18:52:48      1       53.500000        4.218750
# 12305 2019-02-14 08:01:48      1       61.029412        4.382353
# 12306 2019-02-13 11:14:24      1       45.866667        7.533333
# 12307 2019-02-14 02:52:12      1       57.424242       10.757576
#
#        route_description  route_avg_precip  ...  destination_id  \
# 0                  Clear          0.000000  ...      C-d80a1e7d
# 1               Overcast          0.000000  ...      C-639c5e36
# 2                  Clear          0.000000  ...      C-a9f2c329
# 3                  Clear          0.000000  ...      C-c7cacd1d
# 4                    Fog          0.000000  ...      C-ef47bdcd
# ...                  ...               ...  ...             ...
# 12303  Light rain shower          0.037500  ...      C-731988ba
# 12304              Sunny          0.012500  ...      C-a9f2c329
# 12305              Sunny          0.000000  ...      C-c7cacd1d
# 12306  Patchy light snow          0.000000  ...      C-84f378bb
# 12307              Sunny          0.009091  ...      C-c4565ee8
#
#        dest_avg_temp  dest_avg_wind dest_description  dest_avg_precip  \
# 0          31.214286       9.392857    Light drizzle         0.007143
# 1          17.306818       6.085227    Partly cloudy         0.000000
# 2          19.937500       8.437500         Blizzard         0.006250
# 3          21.600000      10.383333       Heavy snow         0.015000
# 4          28.421875       8.351562            Sunny         0.000000
# ...              ...            ...              ...              ...
# 12303      66.997297       3.743243            Clear         0.000000
# 12304      28.994475       9.436464            Sunny         0.004420
# 12305      30.280928      10.427835    Partly cloudy         0.006186
# 12306      35.716763       8.234104            Sunny         0.002023
# 12307      36.507937       8.671958            Sunny         0.010582
#
#        dest_avg_humidity dest_avg_visibility  dest_avg_pressure      avg_nov  \
# 0              78.000000            4.375000        1018.785714  1932.714286
# 1              83.329545            5.306818        1027.062500  1432.937500
# 2              88.000000            4.000000        1020.375000  1763.250000
# 3              79.708333            3.875000        1020.258333  1707.316667
# 4              54.289062            5.851562        1020.062500  1688.554688
# ...                  ...                 ...                ...          ...
# 12303          58.554054            6.000000        1012.751351  1844.054054
# 12304          78.743094            4.994475        1019.604972  1839.093923
# 12305          74.994845            4.337629        1018.030928  1802.474227
# 12306          62.476879            5.705202        1021.274566  1813.329480
# 12307          74.161376            4.891534        1019.277778  1818.645503
#
#        accident
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ...         ...
# 12303         1
# 12304         1
# 12305         1
# 12306         1
# 12307         1
#
# [12308 rows x 31 columns]

# %%
# Lets merge truck_df and driver_df
swodt_truck_merge = swodt_merge.merge(truck_df,on='truck_id',how='left')

# %%
final_data = swodt_truck_merge.merge(driver_df,left_on=['truck_id'],right_on=['vehicle_no'],
                        how='left').drop(columns=['vehicle_no'])

# %%
final_data
# Out:
#        unique_id  truck_id    route_id      departure_date  \
# 0              0  30312694  R-b236e347 2019-01-01 07:00:00
# 1              1  59856374  R-29ea762e 2019-01-01 07:00:00
# 2              2  12602955  R-a3d67783 2019-01-01 07:00:00
# 3              3  46619422  R-31ec9310 2019-01-01 07:00:00
# 4              4  10140178  R-a07c5dbd 2019-01-01 07:00:00
# ...          ...       ...         ...                 ...
# 12303      12303  31047945  R-1484a7ea 2019-02-06 07:00:00
# 12304      12304  14758432  R-927cf900 2019-02-06 07:00:00
# 12305      12305  31370619  R-5a83ad98 2019-02-06 07:00:00
# 12306      12306  67332883  R-991530bc 2019-02-06 07:00:00
# 12307      12307  26630473  R-3f49bd43 2019-02-06 07:00:00
#
#         estimated_arrival  delay  route_avg_temp  route_avg_wind  \
# 0     2019-01-01 13:13:12      0       28.333333        4.333333
# 1     2019-01-02 04:01:12      0       40.000000       10.600000
# 2     2019-01-01 07:45:36      0       24.000000        7.500000
# 3     2019-01-01 20:46:48      0       40.250000        5.250000
# 4     2019-01-01 21:34:11      0       19.500000        4.500000
# ...                   ...    ...             ...             ...
# 12303 2019-02-13 22:40:12      0       60.500000        7.625000
# 12304 2019-02-13 18:52:48      1       53.500000        4.218750
# 12305 2019-02-14 08:01:48      1       61.029412        4.382353
# 12306 2019-02-13 11:14:24      1       45.866667        7.533333
# 12307 2019-02-14 02:52:12      1       57.424242       10.757576
#
#        route_description  route_avg_precip  ...  mileage_mpg  fuel_type  \
# 0                  Clear          0.000000  ...           23     diesel
# 1               Overcast          0.000000  ...           21     diesel
# 2                  Clear          0.000000  ...           26     diesel
# 3                  Clear          0.000000  ...           27     diesel
# 4                    Fog          0.000000  ...           23     diesel
# ...                  ...               ...  ...          ...        ...
# 12303  Light rain shower          0.037500  ...           28     diesel
# 12304              Sunny          0.012500  ...           21     diesel
# 12305              Sunny          0.000000  ...           18        gas
# 12306  Patchy light snow          0.000000  ...           22     diesel
# 12307              Sunny          0.009091  ...           13        gas
#
#         driver_id             name  gender  age experience  driving_style  \
# 0      94ed3e6d-f      Manuel Wise    male   48          9      proactive
# 1      0efc20ea-5    Steven Bishop    male   47         12      proactive
# 2      8b5ca0fd-7     Nathan Baker    male   43          6      proactive
# 3      4d8521f5-6  Andrew Thompson    male   49         16   conservative
# 4      d809c9ce-3    Joel Phillips    male   56         22   conservative
# ...           ...              ...     ...  ...        ...            ...
# 12303  2a819968-b     Brian Vaughn    male   58         11   conservative
# 12304  cc4226d8-b       John Zhang    male   47         16      proactive
# 12305  117112bb-8   Victoria Smith  female   56         21      proactive
# 12306  f48cbc8a-c    James Nichols    male   37          7   conservative
# 12307  d900505e-1      Jason Scott    male   47         11      proactive
#
#        ratings  average_speed_mph
# 0            7              57.36
# 1            8              57.04
# 2            8              64.11
# 3            4              49.47
# 4            9              43.42
# ...        ...                ...
# 12303        4              39.89
# 12304        7              63.88
# 12305        8              60.14
# 12306        3              36.44
# 12307        6              56.60
#
# [12308 rows x 43 columns]

# %%
final_data.columns
# Out:
# Index(['unique_id', 'truck_id', 'route_id', 'departure_date',
#        'estimated_arrival', 'delay', 'route_avg_temp', 'route_avg_wind',
#        'route_description', 'route_avg_precip', 'route_avg_humidity',
#        'route_avg_visibility', 'route_avg_pressure', 'origin_id',
#        'origin_avg_temp', 'origin_avg_wind', 'origin_description',
#        'origin_avg_precip', 'origin_avg_humidity', 'origin_avg_visibility',
#        'origin_avg_pressure', 'destination_id', 'dest_avg_temp',
#        'dest_avg_wind', 'dest_description', 'dest_avg_precip',
#        'dest_avg_humidity', 'dest_avg_visibility', 'dest_avg_pressure',
#        'avg_nov', 'accident', 'truck_age', 'load_capacity_pounds',
#        'mileage_mpg', 'fuel_type', 'driver_id', 'name', 'gender', 'age',
#        'experience', 'driving_style', 'ratings', 'average_speed_mph'],
#       dtype='object')

# %%
final_data.isnull().sum()
# Out:
# unique_id                  0
# truck_id                   0
# route_id                   0
# departure_date             0
# estimated_arrival          0
# delay                      0
# route_avg_temp             0
# route_avg_wind             0
# route_description          0
# route_avg_precip           0
# route_avg_humidity         0
# route_avg_visibility       0
# route_avg_pressure         0
# origin_id                  0
# origin_avg_temp            0
# origin_avg_wind            0
# origin_description         0
# origin_avg_precip          0
# origin_avg_humidity        0
# origin_avg_visibility      0
# origin_avg_pressure        0
# destination_id             0
# dest_avg_temp              0
# dest_avg_wind              0
# dest_description           0
# dest_avg_precip            0
# dest_avg_humidity          0
# dest_avg_visibility        0
# dest_avg_pressure          0
# avg_nov                    0
# accident                   0
# truck_age                  0
# load_capacity_pounds     604
# mileage_mpg                0
# fuel_type                  0
# driver_id                  0
# name                       0
# gender                   234
# age                        0
# experience                 0
# driving_style            477
# ratings                    0
# average_speed_mph          0
# dtype: int64

# %% [markdown]
# # Load - Using Hopsworks (Feature Store) to load final data
#
# Benifits of using feature store:
# * Can be stored and shared within a team.
# * We can have different versions.
# * We can perform analystics.
# * It assures data quality and monitoring.
# * It can be integrated with ML platforms.

# %%
import hopsworks

# %%
api = '****************************************************'
project = hopsworks.login(api_key_value=api)
# Out:
# Connected. Call `.close()` to terminate connection gracefully.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/792725

# %%
fs = project.get_feature_store()
# Out:
# 2024-07-11 01:17:11,492 WARNING: DeprecationWarning: The 'warn' method is deprecated, use 'warning' instead
#
# 2024-07-11 01:17:11,492 WARNING: using legacy validation callback
# Connected. Call `.close()` to terminate connection gracefully.

# %%
# We need to replace null values with 'unknown'

final_data['gender'].fillna('unknown',inplace=True)
final_data['driving_style'].fillna('unknown',inplace=True)

# %%
final_data.isnull().sum()
# Out:
# unique_id                  0
# truck_id                   0
# route_id                   0
# departure_date             0
# estimated_arrival          0
# delay                      0
# route_avg_temp             0
# route_avg_wind             0
# route_description          0
# route_avg_precip           0
# route_avg_humidity         0
# route_avg_visibility       0
# route_avg_pressure         0
# origin_id                  0
# origin_avg_temp            0
# origin_avg_wind            0
# origin_description         0
# origin_avg_precip          0
# origin_avg_humidity        0
# origin_avg_visibility      0
# origin_avg_pressure        0
# destination_id             0
# dest_avg_temp              0
# dest_avg_wind              0
# dest_description           0
# dest_avg_precip            0
# dest_avg_humidity          0
# dest_avg_visibility        0
# dest_avg_pressure          0
# avg_nov                    0
# accident                   0
# truck_age                  0
# load_capacity_pounds     604
# mileage_mpg                0
# fuel_type                  0
# driver_id                  0
# name                       0
# gender                     0
# age                        0
# experience                 0
# driving_style              0
# ratings                    0
# average_speed_mph          0
# dtype: int64

# %%
truck_final_fg = fs.get_or_create_feature_group(name='truck_final',
                                                version=1,
                                                description="Truck ETA Final Data",
                                                primary_key=['unique_id'],
                                                event_time='estimated_arrival',
                                                online_enabled=True)

# %%
truck_final_fg.insert(final_data)
# Out:
# Uploading Dataframe: 0.00% |          | Rows 0/12308 | Elapsed Time: 00:00 | Remaining Time: ?
# Launching job: truck_final_1_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai/p/792725/jobs/named/truck_final_1_offline_fg_materialization/executions
# (<hsfs.core.job.Job at 0x2227f971c70>, None)

# %%
truck_final_fg.statistics_config={'enabled':True,
                                 'correlations':True,
                                 'histograms':True}

# %%
truck_final_fg.update_statistics_config()

# %%
truck_final_fg.compute_statistics()
# Out:
# 2024-07-11 01:17:36,390 WARNING: DeprecationWarning: datetime.datetime.utcfromtimestamp() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.fromtimestamp(timestamp, datetime.UTC).
# Statistics(1720553092358)

# %%
hopsworks.logout()
# Out:
# Connection closed.
